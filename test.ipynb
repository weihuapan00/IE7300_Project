# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.datasets import load_iris

# %%
from DST import DecisionTreeClassifier

# %%
dt = DecisionTreeClassifier()

# %%
df = pd.read_csv("MushroomDataset/secondary_data.csv",sep=";")

# %%
df
# Out:
#       class  cap-diameter cap-shape  ... spore-print-color habitat season
# 0         p         15.26         x  ...               NaN       d      w
# 1         p         16.60         x  ...               NaN       d      u
# 2         p         14.07         x  ...               NaN       d      w
# 3         p         14.17         f  ...               NaN       d      w
# 4         p         14.64         x  ...               NaN       d      w
# ...     ...           ...       ...  ...               ...     ...    ...
# 61064     p          1.18         s  ...               NaN       d      a
# 61065     p          1.27         f  ...               NaN       d      a
# 61066     p          1.27         s  ...               NaN       d      u
# 61067     p          1.24         f  ...               NaN       d      u
# 61068     p          1.17         s  ...               NaN       d      u
#
# [61069 rows x 21 columns]

# %%
y = df[['class']]
X = df.iloc[:,1:]
X = pd.get_dummies(X) # encode categorical data by one-hot-encoding
X = X.astype(float) # convert true and false to 1 and 0
X
# Out:
#        cap-diameter  stem-height  stem-width  ...  season_s  season_u  season_w
# 0             15.26        16.95       17.09  ...       0.0       0.0       1.0
# 1             16.60        17.99       18.19  ...       0.0       1.0       0.0
# 2             14.07        17.80       17.74  ...       0.0       0.0       1.0
# 3             14.17        15.77       15.98  ...       0.0       0.0       1.0
# 4             14.64        16.53       17.20  ...       0.0       0.0       1.0
# ...             ...          ...         ...  ...       ...       ...       ...
# 61064          1.18         3.93        6.22  ...       0.0       0.0       0.0
# 61065          1.27         3.18        5.43  ...       0.0       0.0       0.0
# 61066          1.27         3.86        6.37  ...       0.0       1.0       0.0
# 61067          1.24         3.56        5.44  ...       0.0       1.0       0.0
# 61068          1.17         3.25        5.45  ...       0.0       1.0       0.0
#
# ...

# %%
from sklearn.preprocessing import FunctionTransformer
log_transformer = FunctionTransformer(np.log1p, validate=True)

X_transform = log_transformer.transform(X)
X = pd.DataFrame(X_transform,columns=X.columns)
# Out:
# /Users/weihuapan/anaconda3/lib/python3.11/site-packages/sklearn/base.py:457: UserWarning: X has feature names, but FunctionTransformer was fitted without feature names
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /Users/weihuapan/Desktop/workplace/IE7300/Project3/test.ipynb Cell 7 line 4
#       <a href='vscode-notebook-cell:/Users/weihuapan/Desktop/workplace/IE7300/Project3/test.ipynb#X15sZmlsZQ%3D%3D?line=0'>1</a> from sklearn.preprocessing import FunctionTransformer
#       <a href='vscode-notebook-cell:/Users/weihuapan/Desktop/workplace/IE7300/Project3/test.ipynb#X15sZmlsZQ%3D%3D?line=1'>2</a> log_transformer = FunctionTransformer(np.log1p, validate=True)
# ----> <a href='vscode-notebook-cell:/Users/weihuapan/Desktop/workplace/IE7300/Project3/test.ipynb#X15sZmlsZQ%3D%3D?line=3'>4</a> X_transform = log_transformer.transform(X)
# ...

# %%
X['stem-width'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
y.shape
# Out:
# (61069, 1)

# %%
dt.fit(X,y)
